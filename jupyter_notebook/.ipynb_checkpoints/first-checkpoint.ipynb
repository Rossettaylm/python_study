# %% [markdown]
# ### test

# %%
import matplotlib.pyplot as plt
import math

x = [value / 100 for value in range(100)]
y = [math.sin(value) for value in x]
plt.plot(x, y)
plt.title("Sin Image")
plt.show()
